# %% [markdown]
# # Visualising Synthetic Seismic Data to perform fast automated structural analysis for seismic sections

# %% [markdown]
# ## Revolutionizes Seismic Image Interpretation with Advanced Deep Learning, using CNNs

# %% [markdown]
# ## Visualised Labelled Synthetic Seismic Data
#
# <img src="https://i.imgur.com/Mg3sJZo.jpg">
#
# Welcome to Visualised Labelled Synthetic Seismic Data on Automatic Seismic Interpretation!

# %%
from pylabel import importer
import logging

# %%
#Specify path to the coco.json file
path_to_annotations = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\trainval.json"
#Specify the path to the images (if they are in a different folder than the annotations)
path_to_images = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\images"

# %%
#Import the dataset into the pylable schema 
dataset = importer.ImportCoco(path_to_annotations, path_to_images=path_to_images, name="BCCD_coco")
dataset.df.head(5)
# Out:
#                                            img_folder  \
# id
# 0   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 1   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 2   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 3   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 4   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
#
#                              img_filename img_path  img_id  img_width  \
# id
# 0   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 1   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 2   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 3   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 4   acoustic_impedance_Sc_10_Emscher_.png                0       2160
#
#     img_height img_depth ann_segmented  ann_bbox_xmin  ann_bbox_ymin  ...  \
# id                                                                    ...
# 0          720                                  192.0          289.0  ...
# 1          720                                  212.0          287.0  ...
# 2          720                                  346.0          293.0  ...
# 3          720                                  382.0          278.0  ...
# 4          720                                  437.0          272.0  ...
#
#                                      ann_segmentation  ann_iscrowd  ann_pose  \
# id
# 0   [[250.30303030303028, 432.12121212121207, 215....            0
# 1   [[212.72727272727272, 287.8787878787879, 235.1...            0
# 2   [[346.66666666666663, 293.93939393939394, 366....            0
# 3   [[382.4242424242424, 281.2121212121212, 409.69...            0
# 4   [[437.57575757575756, 276.96969696969694, 463....            0
#
#     ann_truncated  ann_difficult cat_id  cat_name cat_supercategory split  \
# id
# 0                                     0     fault             fault
# 1                                     0     fault             fault
# 2                                     0     fault             fault
# 3                                     0     fault             fault
# 4                                     0     fault             fault
#
#    annotated
# id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 25 columns]

# %%
dataset.df[dataset.df['img_filename'] == 'acoustic_impedance_Sc_10_Emscher_.png']
# Out:
#                                            img_folder  \
# id
# 0   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 1   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 2   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 3   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 4   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# ..                                                ...
# 58  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 59  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 60  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 61  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 62  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
#
#                              img_filename img_path  img_id  img_width  \
# id
# 0   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 1   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 2   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 3   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 4   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# ..                                    ...      ...     ...        ...
# 58  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 59  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 60  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 61  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 62  acoustic_impedance_Sc_10_Emscher_.png                0       2160
#
#     img_height img_depth ann_segmented  ann_bbox_xmin  ann_bbox_ymin  ...  \
# id                                                                    ...
# 0          720                                  192.0          289.0  ...
# 1          720                                  212.0          287.0  ...
# 2          720                                  346.0          293.0  ...
# 3          720                                  382.0          278.0  ...
# 4          720                                  437.0          272.0  ...
# ..         ...       ...           ...            ...            ...  ...
# 58         720                                  508.0          203.0  ...
# 59         720                                  363.0          378.0  ...
# 60         720                                  703.0          536.0  ...
# 61         720                                 1208.0          190.0  ...
# 62         720                                 1518.0          174.0  ...
#
#                                      ann_segmentation  ann_iscrowd  ann_pose  \
# id
# 0   [[250.30303030303028, 432.12121212121207, 215....            0
# 1   [[212.72727272727272, 287.8787878787879, 235.1...            0
# 2   [[346.66666666666663, 293.93939393939394, 366....            0
# 3   [[382.4242424242424, 281.2121212121212, 409.69...            0
# 4   [[437.57575757575756, 276.96969696969694, 463....            0
# ..                                                ...          ...       ...
# 58  [[508.48484848484844, 256.3636363636363, 514.5...            0
# 59  [[366.060606060606, 378.78787878787875, 363.03...            0
# 60  [[703.030303030303, 536.9696969696969, 707.272...            0
# 61  [[1208.4848484848485, 198.18181818181816, 1256...            0
# 62  [[1518.181818181818, 184.24242424242422, 1578....            0
#
#     ann_truncated  ann_difficult cat_id  cat_name cat_supercategory split  \
# id
# 0                                     0     fault             fault
# 1                                     0     fault             fault
# 2                                     0     fault             fault
# 3                                     0     fault             fault
# 4                                     0     fault             fault
# ..            ...            ...    ...       ...               ...   ...
# 58                                    1      flat              flat
# 59                                    1      flat              flat
# 60                                    1      flat              flat
# 61                                    2      fold              fold
# 62                                    2      fold              fold
#
#    annotated
# id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 58         1
# 59         1
# 60         1
# 61         1
# 62         1
#
# [63 rows x 25 columns]

# %%
dataset.df[(dataset.df['img_filename'] == 'acoustic_impedance_Sc_10_Emscher_.png') & (dataset.df['cat_name'] == 'flat')][:]
# Out:
#                                            img_folder  \
# id
# 47  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 48  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 49  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 50  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 51  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 52  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 53  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 54  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 55  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 56  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 57  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 58  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 59  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 60  C:\Users\r04ra18\Desktop\Object-Detection-Mode...
#
#                              img_filename img_path  img_id  img_width  \
# id
# 47  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 48  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 49  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 50  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 51  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 52  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 53  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 54  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 55  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 56  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 57  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 58  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 59  acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 60  acoustic_impedance_Sc_10_Emscher_.png                0       2160
#
#     img_height img_depth ann_segmented  ann_bbox_xmin  ann_bbox_ymin  ...  \
# id                                                                    ...
# 47         720                                 1264.0          217.0  ...
# 48         720                                  513.0          396.0  ...
# 49         720                                  517.0          300.0  ...
# 50         720                                  707.0          326.0  ...
# 51         720                                  839.0          300.0  ...
# 52         720                                  675.0          422.0  ...
# 53         720                                  515.0          510.0  ...
# 54         720                                  270.0          311.0  ...
# 55         720                                  259.0          352.0  ...
# 56         720                                  313.0          464.0  ...
# 57         720                                  246.0          279.0  ...
# 58         720                                  508.0          203.0  ...
# 59         720                                  363.0          378.0  ...
# 60         720                                  703.0          536.0  ...
#
#                                      ann_segmentation  ann_iscrowd  ann_pose  \
# id
# 47  [[1275.151515151515, 217.57575757575756, 1264....            0
# 48  [[530.3030303030303, 396.3636363636363, 513.33...            0
# 49  [[526.060606060606, 300.60606060606057, 517.57...            0
# 50  [[707.2727272727273, 333.3333333333333, 707.27...            0
# 51  [[839.3939393939394, 321.8181818181818, 858.18...            0
# 52  [[681.2121212121211, 422.4242424242424, 675.15...            0
# 53  [[525.4545454545454, 510.30303030303025, 515.1...            0
# 54  [[272.7272727272727, 311.5151515151515, 270.90...            0
# 55  [[259.3939393939394, 352.7272727272727, 261.81...            0
# 56  [[341.8181818181818, 464.2424242424242, 313.93...            0
# 57  [[246.66666666666666, 283.6363636363636, 253.3...            0
# 58  [[508.48484848484844, 256.3636363636363, 514.5...            0
# 59  [[366.060606060606, 378.78787878787875, 363.03...            0
# 60  [[703.030303030303, 536.9696969696969, 707.272...            0
#
#     ann_truncated  ann_difficult cat_id  cat_name cat_supercategory split  \
# id
# 47                                    1      flat              flat
# 48                                    1      flat              flat
# 49                                    1      flat              flat
# 50                                    1      flat              flat
# 51                                    1      flat              flat
# 52                                    1      flat              flat
# 53                                    1      flat              flat
# 54                                    1      flat              flat
# 55                                    1      flat              flat
# 56                                    1      flat              flat
# 57                                    1      flat              flat
# 58                                    1      flat              flat
# 59                                    1      flat              flat
# 60                                    1      flat              flat
#
#    annotated
# id
# 47         1
# 48         1
# 49         1
# 50         1
# 51         1
# 52         1
# 53         1
# 54         1
# 55         1
# 56         1
# 57         1
# 58         1
# 59         1
# 60         1
#
# [14 rows x 25 columns]

# %%
dataset.df[dataset.df['img_filename'] == 'acoustic_impedance_Sc_10_Emscher_.png']['ann_bbox_ymax']
# Out:
# id
# 0     432.0
# 1     324.0
# 2     413.0
# 3     335.0
# 4     459.0
#       ...
# 58    280.0
# 59    442.0
# 60    578.0
# 61    621.0
# 62    622.0
# Name: ann_bbox_ymax, Length: 63, dtype: float64

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes:{dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
print(f"Path to annotations:\n{dataset.path_to_annotations}")
# Out:
# Number of images: 45
# Number of classes: 3
# Classes:['fault', 'flat', 'fold']
# Class counts:
# fold     887
# fault    824
# flat     225
# Name: cat_name, dtype: int64
# Path to annotations:
# C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train

# %%
from IPython.display import Image, display
display(dataset.visualize.ShowBoundingBoxes(10))
display(dataset.visualize.ShowBoundingBoxes(1))
display(dataset.visualize.ShowBoundingBoxes(2))
display(dataset.visualize.ShowBoundingBoxes(5))
# Out:
# <PIL.Image.Image image mode=RGB size=2160x720>
# <PIL.Image.Image image mode=RGB size=2160x720>
# <PIL.Image.Image image mode=RGB size=2160x720>
# <PIL.Image.Image image mode=RGB size=2160x720>

# %%
## Convert the labels

# %%
# run this code to convert from the json to text Yolov5 formate
dataset.path_to_annotations = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\trainval.json"
dataset.export.ExportToYoloV5()[0]
# Out:
# Exporting YOLO files...: 100%|████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 189.59it/s]
# 'training\\dataset.yaml'

# %%
##############################################

# %%
import logging
from pylabel import importer
logging.getLogger().setLevel(logging.CRITICAL)

# %%
#Specify path to the coco.json file
path_to_annotations = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\trainval.json"
#Specify the path to the images (if they are in a different folder than the annotations)
path_to_images = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\images"

# %%
#Import the dataset into the pylable schema 
dataset = importer.ImportCoco(path_to_annotations, path_to_images=path_to_images, name="Segmentation")
dataset.df.head(5)
# Out:
#                                            img_folder  \
# id
# 0   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 1   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 2   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 3   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
# 4   C:\Users\r04ra18\Desktop\Object-Detection-Mode...
#
#                              img_filename img_path  img_id  img_width  \
# id
# 0   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 1   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 2   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 3   acoustic_impedance_Sc_10_Emscher_.png                0       2160
# 4   acoustic_impedance_Sc_10_Emscher_.png                0       2160
#
#     img_height img_depth ann_segmented  ann_bbox_xmin  ann_bbox_ymin  ...  \
# id                                                                    ...
# 0          720                                  192.0          289.0  ...
# 1          720                                  212.0          287.0  ...
# 2          720                                  346.0          293.0  ...
# 3          720                                  382.0          278.0  ...
# 4          720                                  437.0          272.0  ...
#
#                                      ann_segmentation  ann_iscrowd  ann_pose  \
# id
# 0   [[250.30303030303028, 432.12121212121207, 215....            0
# 1   [[212.72727272727272, 287.8787878787879, 235.1...            0
# 2   [[346.66666666666663, 293.93939393939394, 366....            0
# 3   [[382.4242424242424, 281.2121212121212, 409.69...            0
# 4   [[437.57575757575756, 276.96969696969694, 463....            0
#
#     ann_truncated  ann_difficult cat_id  cat_name cat_supercategory split  \
# id
# 0                                     0     fault             fault
# 1                                     0     fault             fault
# 2                                     0     fault             fault
# 3                                     0     fault             fault
# 4                                     0     fault             fault
#
#    annotated
# id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#
# [5 rows x 25 columns]

# %%
dataset.path_to_annotations = "data/yolo"
dataset.export.ExportToYoloV5(segmentation=True)[1]
# Out:
# Exporting YOLO files...: 100%|█████████████████████████████████████████████████████████| 45/45 [00:08<00:00,  5.11it/s]
# 'training\\labels\\acoustic_impedance_Sc_10_Emscher_.txt'

# %%
# run this code to convert from the json to text Yolov5 format
dataset.path_to_annotations = r"C:\Users\r04ra18\Desktop\Object-Detection-Model\Dataset\Train\trainval.json"
dataset.export.ExportToYoloV5()[0]
# Out:
# Exporting YOLO files...: 100%|████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 228.75it/s]
# 'training\\dataset.yaml'

# %% [markdown]
# #### Thank you!!

# %% [markdown]
# #### By: Ramy Abdallah
